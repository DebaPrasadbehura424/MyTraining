# %%
import numpy as np

# %%
array=np.array([1,2,3,4])
array
# Out:
# array([1, 2, 3, 4])

# %%
array2=np.array([[1,2,3,4],[2,3,4,6]])
array2
# Out:
# array([[1, 2, 3, 4],
#        [2, 3, 4, 6]])

# %%
array2.shape
array2.size
# Out:
# 8

# %%
a= np.ones(3)
a
# Out:
# array([1., 1., 1.])

# %%
a= np.zeros(3)
a= np.zeros((1,3)) 
a= np.zeros((1,3),dtype='int') 
a
# Out:
# array([[0, 0, 0]])
