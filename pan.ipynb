# %%
import pandas as pd;
s= pd.Series([10,11,12])
s
# s.dtype
# Out:
# dtype('int64')

# %%
labels=['A','B','C']
s= pd.Series([10,11,12],labels)
s
# s.index=labels
# s
# Out:
# A    10
# B    11
# C    12
# dtype: int64

# %%
print(s[0:2])
print(s['A':'B'])
# Out:
# A    10
# B    11
# dtype: int64
# A    10
# B    11
# dtype: int64

# %%
s.iloc[2:3]
# Out:
# C    12
# dtype: int64

# %%
s.loc["A":"C"]
# Out:
# A    10
# B    11
# C    12
# dtype: int64

# %%
Fruit_portion = {
    "mango" : 2.0,
    "Apple":0.1,
    "PineApple" : 0.5,
    "Avocardo" : 1.2,
    "Grapes" : 1.5,
    "Kiwi" : 2.1,
    "Cherry" : 1.8,
    "BlackBerry" : 0.6,
    "A": 1.1,
    "B" : 1.2
}

s2= pd.Series(Fruit_portion,name="portion");
s2
# Out:
# mango         2.0
# Apple         0.1
# PineApple     0.5
# Avocardo      1.2
# Grapes        1.5
# Kiwi          2.1
# Cherry        1.8
# BlackBerry    0.6
# A             1.1
# B             1.2
# Name: portion, dtype: float64

# %%
# s2[s2>1]
# s2[(s2>0.5) & (s2<2.0)]
# s2[(s2>0.5) | (s2<2.0)]
s2[~(s2>1)]
# Out:
# Apple         0.1
# PineApple     0.5
# BlackBerry    0.6
# Name: portion, dtype: float64

# %%
s2["mango"]
# Out:
# np.float64(2.0)

# %%
import numpy as np;

data = {
    "name": np.array(["A", "B", "C", "D"]),
    "marks": np.array([ np.nan, 72, 72, 64]),
    "age": np.array([21, 22, np.nan, 23])
}

df = pd.DataFrame(data);
df
# Out:
#   name  marks   age
# 0    A    NaN  21.0
# 1    B   72.0  22.0
# 2    C   72.0   NaN
# 3    D   64.0  23.0

# %%
df.head()
#  print all the table
# Out:
#   name  marks   age
# 0    A    NaN  21.0
# 1    B   72.0  22.0
# 2    C   91.0   NaN
# 3    D   64.0  23.0

# %%
df.head(3)
#  print 0 to 3
# Out:
#   name  marks   age
# 0    A    NaN  21.0
# 1    B   72.0  22.0
# 2    C   91.0   NaN

# %%
df.tail(1)
# Out:
#   name  marks   age
# 3    D   64.0  23.0

# %%
df.tail(3)
#  print from 3 to 1 tala adu
# Out:
#   name  marks   age
# 1    B   72.0  22.0
# 2    C   72.0   NaN
# 3    D   64.0  23.0

# %%
df.iloc[1:3]
# print 1  to 2
# Out:
#   name  marks   age
# 1    B   72.0  22.0
# 2    C   91.0   NaN

# %%
df.loc[1:3]
# print 1 to 3
# Out:
#   name  marks   age
# 1    B   72.0  22.0
# 2    C   91.0   NaN
# 3    D   64.0  23.0

# %%
df['marks']
# Out:
# 0     NaN
# 1    72.0
# 2    91.0
# 3    64.0
# Name: marks, dtype: float64

# %%
df[['name','marks']]
# Out:
#   name  marks
# 0    A    NaN
# 1    B   72.0
# 2    C   91.0
# 3    D   64.0

# %%
df.drop('age',axis=1)
# Out:
#   name  marks
# 0    A    NaN
# 1    B   72.0
# 2    C   91.0
# 3    D   64.0

# %%
# df.shape[4]

# df.info()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df.shape[4]
#       3 # df.info()
#
# IndexError: tuple index out of range

# %%
df.describe()
# Out:
#            marks   age
# count   3.000000   3.0
# mean   69.333333  22.0
# std     4.618802   1.0
# min    64.000000  21.0
# 25%    68.000000  21.5
# 50%    72.000000  22.0
# 75%    72.000000  22.5
# max    72.000000  23.0

# %%
df["marks"].unique();
df
# df
# Out:
#   name  marks   age
# 0    A    NaN  21.0
# 1    B   72.0  22.0
# 2    C   72.0   NaN
# 3    D   64.0  23.0

# %%
df.isnull().sum()
df
# Out:
#   name  marks   age
# 0    A    NaN  21.0
# 1    B   72.0  22.0
# 2    C   72.0   NaN
# 3    D   64.0  23.0
