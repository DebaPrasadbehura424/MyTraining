# %%
import pandas as pd;
s= pd.Series([10,11,12])
s
# s.dtype
# Out:
# dtype('int64')

# %%
labels=['A','B','C']
s= pd.Series([10,11,12],labels)
s
# Out:
# A    10
# B    11
# C    12
# dtype: int64
